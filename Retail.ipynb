# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasundharadevi-kanikicherla/Pandas-introduction-/blob/main/Retail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
# mount the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#read file from the drive
import pandas as pd

# %%
datasetpath = '/content/drive/MyDrive/Document from Vasundhara Devi'

# %%
import pandas as pd

# %%
df = pd.read_csv(datasetpath)

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# ...

# %%
df['Price'].sum()
# Out:
# 28215

# %%
df['ProductID'].mode()[0]
# Out:
# 523

# %%
amountgreaterthan200 = df['Price']>200

# %%
df[amountgreaterthan200]
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 1           T002      2024-01-02      103        1226        542
# 3           T004      2024-01-04      103        1793        560
# 5           T006      2024-01-06      103        1836        515
# 7           T008      2024-01-08      101        1806        569
# 8           T009      2024-01-09      101        1925        548
# ..           ...             ...      ...         ...        ...
# 92          T093      2024-04-02      102        1408        519
# 94          T095      2024-04-04      103        1980        529
# 95          T096      2024-04-05      101        1918        559
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 1             Toys         2    317       Debit      10.0
# 3        Furniture         6    496       Debit      10.0
# ...

# %%
df.groupby('CustomerID')['Price'].sum()
# Out:
# CustomerID
# 1013    390
# 1082    315
# 1135    157
# 1161    369
# 1169    328
#        ...
# 1950    278
# 1954    109
# 1978    345
# 1980    309
# 1983    170
# Name: Price, Length: 93, dtype: int64

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df.plot(x='Price',y='CustomerID',kind='bar')
plt.xlabel('Price')
plt.ylabel('CustomerID')
plt.show()
