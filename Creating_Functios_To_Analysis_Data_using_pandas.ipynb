# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasundharadevi-kanikicherla/Pandas-introduction-/blob/main/Creating_Functios_To_Analysis_Data_using_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
# mount the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#read file from the drive
import pandas as pd

# %%
datasetpath = '/content/drive/MyDrive/matches_1930_2022.csv'

# %%
df = pd.read_csv(datasetpath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df.shape
# Out:
# (964, 44)

# %%
age = []
height = []
weight = []

# %%
df.shape
# Out:
# (964, 44)

# %%
import random

# %%
#Loop comprehension
[age.append(random.randint(18,40))for _ in range(964)]
print(f"Age is now having {len(age)}")
# Out:
# Age is now having 964

# %%
age
# Out:
# [32,
#  29,
#  36,
#  37,
#  25,
#  25,
#  32,
#  27,
#  31,
#  34,
#  37,
#  39,
#  28,
#  23,
#  22,
#  31,
#  39,
#  31,
#  19,
#  34,
#  26,
#  34,
#  18,
#  27,
#  27,
#  25,
#  20,
#  36,
#  23,
#  29,
#  37,
#  28,
#  39,
#  21,
#  22,
#  23,
#  23,
#  20,
#  35,
#  24,
#  40,
#  34,
#  30,
#  32,
#  31,
#  33,
#  35,
#  34,
#  28,
#  24,
#  38,
#  26,
#  30,
#  22,
#  32,
#  39,
#  29,
#  35,
#  19,
#  21,
#  28,
#  30,
#  31,
#  26,
#  22,
#  28,
#  19,
#  30,
#  22,
#  27,
#  21,
#  18,
#  34,
#  35,
#  21,
#  35,
#  24,
#  19,
#  24,
#  29,
#  23,
#  21,
#  34,
#  25,
#  37,
#  23,
#  21,
#  19,
#  20,
#  18,
#  25,
#  34,
#  19,
#  37,
#  28,
#  18,
#  37,
#  40,
#  37,
#  32,
#  27,
#  25,
#  39,
#  33,
#  19,
#  23,
#  26,
#  32,
#  30,
#  28,
#  24,
#  36,
#  37,
#  29,
#  39,
#  23,
#  28,
#  36,
#  32,
#  37,
#  34,
#  29,
#  20,
#  18,
#  18,
#  21,
#  31,
#  29,
#  18,
#  20,
#  18,
#  33,
#  18,
#  27,
#  37,
#  30,
#  32,
#  31,
#  20,
#  37,
#  18,
#  39,
# ...

# %%
#Adding a new column Data frame
#syntax:df['New column Name']list/series of elements

# %%
df['yearsofExperience']= age

# %%
age
# Out:
# [32,
#  29,
#  36,
#  37,
#  25,
#  25,
#  32,
#  27,
#  31,
#  34,
#  37,
#  39,
#  28,
#  23,
#  22,
#  31,
#  39,
#  31,
#  19,
#  34,
#  26,
#  34,
#  18,
#  27,
#  27,
#  25,
#  20,
#  36,
#  23,
#  29,
#  37,
#  28,
#  39,
#  21,
#  22,
#  23,
#  23,
#  20,
#  35,
#  24,
#  40,
#  34,
#  30,
#  32,
#  31,
#  33,
#  35,
#  34,
#  28,
#  24,
#  38,
#  26,
#  30,
#  22,
#  32,
#  39,
#  29,
#  35,
#  19,
#  21,
#  28,
#  30,
#  31,
#  26,
#  22,
#  28,
#  19,
#  30,
#  22,
#  27,
#  21,
#  18,
#  34,
#  35,
#  21,
#  35,
#  24,
#  19,
#  24,
#  29,
#  23,
#  21,
#  34,
#  25,
#  37,
#  23,
#  21,
#  19,
#  20,
#  18,
#  25,
#  34,
#  19,
#  37,
#  28,
#  18,
#  37,
#  40,
#  37,
#  32,
#  27,
#  25,
#  39,
#  33,
#  19,
#  23,
#  26,
#  32,
#  30,
#  28,
#  24,
#  36,
#  37,
#  29,
#  39,
#  23,
#  28,
#  36,
#  32,
#  37,
#  34,
#  29,
#  20,
#  18,
#  18,
#  21,
#  31,
#  29,
#  18,
#  20,
#  18,
#  33,
#  18,
#  27,
#  37,
#  30,
#  32,
#  31,
#  20,
#  37,
#  18,
#  39,
# ...

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df['Asp']=df['yearsofExperience']*df['home_score']

# %%
df.shape
# Out:
# (964, 46)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df['Asp'].plot(kind='bar',color='red')
# Out:
# <Axes: >

# %%
df.plot(x='yearsofExperience',y='Asp',kind='scatter',color='blue')
# Out:
# <Axes: xlabel='yearsofExperience', ylabel='Asp'>

# %%
df.plot(x='Asp',y=['away_score','home_score'],kind='bar',color=['green', 'red'])
# Out:
# <Axes: xlabel='Asp'>

# %%
# Error:same length_NaN_Not a Number_dtype_Numpy_Q

# %%
def getGraph(DataFrame,column1,column2):
  from matplotlib import pyplot as plt
  if len(DataFrame[column1])==len(DataFrame[column2]):
      df.plot(x=column1,y=column2,kind='bar',color=['pink','black'])
      print('the graph/plot is successfully created ')

  else:
     print('please check the column size once')

# %%
getGraph (df,'home_score','away_score')
# Out:
# the graph/plot is successfully created
